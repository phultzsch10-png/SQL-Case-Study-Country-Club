# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT *
        FROM FACILITIES
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
main()
# Out:
# 2.6.0
# 2. Query all tasks
# (0, 'Tennis Court 1', 5, 25, 10000, 200)
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (2, 'Badminton Court', 0, 15.5, 4000, 50)
# (3, 'Table Tennis', 0, 5, 320, 10)
# (4, 'Massage Room 1', 9.9, 80, 4000, 3000)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)
# (6, 'Squash Court', 3.5, 17.5, 5000, 80)
# (7, 'Snooker Table', 0, 5, 450, 15)
# (8, 'Pool Table', 0, 5, 400, 15)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15228\2264331103.py:14: DeprecationWarning: version is deprecated and will be removed in Python 3.14
#   print(sqlite3.version)

# %%
import pandas as pd

conn = sqlite3.connect("sqlite_db_pythonsqlite.db")

def run_query(query):
    return pd.read_sql_query(query, conn)

# %%
run_query("""
SELECT *
FROM Facilities
""")
# Out:
#    facid             name  membercost  guestcost  initialoutlay  \
# 0      0   Tennis Court 1         5.0       25.0          10000
# 1      1   Tennis Court 2         5.0       25.0           8000
# 2      2  Badminton Court         0.0       15.5           4000
# 3      3     Table Tennis         0.0        5.0            320
# 4      4   Massage Room 1         9.9       80.0           4000
# 5      5   Massage Room 2         9.9       80.0           4000
# 6      6     Squash Court         3.5       17.5           5000
# 7      7    Snooker Table         0.0        5.0            450
# 8      8       Pool Table         0.0        5.0            400
#
#    monthlymaintenance
# 0                 200
# 1                 200
# 2                  50
# 3                  10
# 4                3000
# 5                3000
# 6                  80
# 7                  15
# 8                  15

# %% [markdown]
# Q1

# %%
run_query("""
SELECT name
FROM Facilities
WHERE membercost > 0
""")
# Out:
#              name
# 0  Tennis Court 1
# 1  Tennis Court 2
# 2  Massage Room 1
# 3  Massage Room 2
# 4    Squash Court

# %% [markdown]
# Q2

# %%
run_query("""
SELECT COUNT(*) AS free_facilities
FROM Facilities
WHERE membercost = 0
""")
# Out:
#    free_facilities
# 0                4

# %% [markdown]
# Q3

# %%
run_query("""
SELECT facid, name, membercost, monthlymaintenance
FROM Facilities
WHERE membercost > 0
  AND membercost < monthlymaintenance * 0.2
""")
# Out:
#    facid            name  membercost  monthlymaintenance
# 0      0  Tennis Court 1         5.0                 200
# 1      1  Tennis Court 2         5.0                 200
# 2      4  Massage Room 1         9.9                3000
# 3      5  Massage Room 2         9.9                3000
# 4      6    Squash Court         3.5                  80

# %% [markdown]
# Q4

# %%
run_query("""
SELECT *
FROM Facilities
WHERE facid IN (1, 5)
""")
# Out:
#    facid            name  membercost  guestcost  initialoutlay  \
# 0      1  Tennis Court 2         5.0         25           8000
# 1      5  Massage Room 2         9.9         80           4000
#
#    monthlymaintenance
# 0                 200
# 1                3000

# %% [markdown]
# Q5

# %%
run_query("""
SELECT name,
       monthlymaintenance,
       CASE WHEN monthlymaintenance > 100 THEN 'expensive'
            ELSE 'cheap' END AS cost_label
FROM Facilities
""")
# Out:
#               name  monthlymaintenance cost_label
# 0   Tennis Court 1                 200  expensive
# 1   Tennis Court 2                 200  expensive
# 2  Badminton Court                  50      cheap
# 3     Table Tennis                  10      cheap
# 4   Massage Room 1                3000  expensive
# 5   Massage Room 2                3000  expensive
# 6     Squash Court                  80      cheap
# 7    Snooker Table                  15      cheap
# 8       Pool Table                  15      cheap

# %% [markdown]
# Q6

# %%
run_query("""
SELECT firstname, surname, joindate
FROM Members
WHERE joindate = (SELECT MAX(joindate) FROM Members)
""")
# Out:
#   firstname surname             joindate
# 0    Darren   Smith  2012-09-26 18:08:45

# %% [markdown]
# Q7

# %%
run_query("""
SELECT DISTINCT f.name AS facility,
       m.firstname || ' ' || m.surname AS member_name
FROM Bookings AS b
INNER JOIN Facilities AS f ON b.facid = f.facid
INNER JOIN Members AS m ON b.memid = m.memid
WHERE f.name LIKE 'Tennis Court%'
  AND m.memid != 0
ORDER BY member_name
""")
# Out:
#           facility        member_name
# 0   Tennis Court 1         Anne Baker
# 1   Tennis Court 2         Anne Baker
# 2   Tennis Court 2       Burton Tracy
# 3   Tennis Court 1       Burton Tracy
# 4   Tennis Court 1       Charles Owen
# 5   Tennis Court 2       Charles Owen
# 6   Tennis Court 2       Darren Smith
# 7   Tennis Court 1      David Farrell
# 8   Tennis Court 2      David Farrell
# 9   Tennis Court 2        David Jones
# 10  Tennis Court 1        David Jones
# 11  Tennis Court 1       David Pinker
# 12  Tennis Court 1      Douglas Jones
# 13  Tennis Court 1      Erica Crumpet
# 14  Tennis Court 2     Florence Bader
# 15  Tennis Court 1     Florence Bader
# 16  Tennis Court 1     Gerald Butters
# 17  Tennis Court 2     Gerald Butters
# 18  Tennis Court 2   Henrietta Rumney
# 19  Tennis Court 1         Jack Smith
# 20  Tennis Court 2         Jack Smith
# 21  Tennis Court 1    Janice Joplette
# 22  Tennis Court 2    Janice Joplette
# 23  Tennis Court 2     Jemima Farrell
# 24  Tennis Court 1     Jemima Farrell
# 25  Tennis Court 1        Joan Coplin
# 26  Tennis Court 1          John Hunt
# 27  Tennis Court 2          John Hunt
# 28  Tennis Court 1    Matthew Genting
# 29  Tennis Court 2  Millicent Purview
# 30  Tennis Court 2         Nancy Dare
# 31  Tennis Court 1         Nancy Dare
# 32  Tennis Court 2    Ponder Stibbons
# 33  Tennis Court 1    Ponder Stibbons
# 34  Tennis Court 2   Ramnaresh Sarwin
# 35  Tennis Court 1   Ramnaresh Sarwin
# 36  Tennis Court 2         Tim Boothe
# 37  Tennis Court 1         Tim Boothe
# 38  Tennis Court 2         Tim Rownam
# 39  Tennis Court 1         Tim Rownam
# 40  Tennis Court 2      Timothy Baker
# 41  Tennis Court 1      Timothy Baker
# 42  Tennis Court 1        Tracy Smith
# 43  Tennis Court 2        Tracy Smith

# %% [markdown]
# Q8

# %%
run_query("""
SELECT f.name AS facility,
       m.firstname || ' ' || m.surname AS member_name,
       CASE WHEN b.memid = 0 THEN f.guestcost * b.slots
            ELSE f.membercost * b.slots END AS cost
FROM Bookings AS b
INNER JOIN Facilities AS f ON b.facid = f.facid
INNER JOIN Members AS m ON b.memid = m.memid
WHERE DATE(b.starttime) = '2012-09-14'
  AND CASE WHEN b.memid = 0 THEN f.guestcost * b.slots
           ELSE f.membercost * b.slots END > 30
ORDER BY cost DESC
""")
# Out:
#           facility     member_name   cost
# 0   Massage Room 2     GUEST GUEST  320.0
# 1   Massage Room 1     GUEST GUEST  160.0
# 2   Massage Room 1     GUEST GUEST  160.0
# 3   Massage Room 1     GUEST GUEST  160.0
# 4   Tennis Court 2     GUEST GUEST  150.0
# 5   Tennis Court 1     GUEST GUEST   75.0
# 6   Tennis Court 1     GUEST GUEST   75.0
# 7   Tennis Court 2     GUEST GUEST   75.0
# 8     Squash Court     GUEST GUEST   70.0
# 9   Massage Room 1  Jemima Farrell   39.6
# 10    Squash Court     GUEST GUEST   35.0
# 11    Squash Court     GUEST GUEST   35.0

# %% [markdown]
# Q9

# %%
run_query("""
SELECT facility, member_name, cost
FROM (
    SELECT f.name AS facility,
           m.firstname || ' ' || m.surname AS member_name,
           CASE WHEN b.memid = 0 THEN f.guestcost * b.slots
                ELSE f.membercost * b.slots END AS cost
    FROM Bookings AS b
    INNER JOIN Facilities AS f ON b.facid = f.facid
    INNER JOIN Members AS m ON b.memid = m.memid
    WHERE DATE(b.starttime) = '2012-09-14'
) AS booking_costs
WHERE cost > 30
ORDER BY cost DESC
""")
# Out:
#           facility     member_name   cost
# 0   Massage Room 2     GUEST GUEST  320.0
# 1   Massage Room 1     GUEST GUEST  160.0
# 2   Massage Room 1     GUEST GUEST  160.0
# 3   Massage Room 1     GUEST GUEST  160.0
# 4   Tennis Court 2     GUEST GUEST  150.0
# 5   Tennis Court 1     GUEST GUEST   75.0
# 6   Tennis Court 1     GUEST GUEST   75.0
# 7   Tennis Court 2     GUEST GUEST   75.0
# 8     Squash Court     GUEST GUEST   70.0
# 9   Massage Room 1  Jemima Farrell   39.6
# 10    Squash Court     GUEST GUEST   35.0
# 11    Squash Court     GUEST GUEST   35.0

# %% [markdown]
# Q10

# %%
run_query("""
SELECT f.name AS facility,
       SUM(CASE WHEN b.memid = 0 THEN f.guestcost * b.slots
                ELSE f.membercost * b.slots END) AS total_revenue
FROM Bookings AS b
INNER JOIN Facilities AS f ON b.facid = f.facid
GROUP BY f.name
HAVING total_revenue < 1000
ORDER BY total_revenue
""")
# Out:
#         facility  total_revenue
# 0   Table Tennis            180
# 1  Snooker Table            240
# 2     Pool Table            270

# %% [markdown]
# Q11

# %%
run_query("""
SELECT m.surname AS member_surname,
       m.firstname AS member_firstname,
       r.surname AS recommender_surname,
       r.firstname AS recommender_firstname
FROM Members AS m
INNER JOIN Members AS r ON m.recommendedby = r.memid
WHERE m.memid != 0
ORDER BY m.surname, m.firstname
""")
# Out:
#        member_surname member_firstname recommender_surname  \
# 0               Bader         Florence            Stibbons
# 1               Baker             Anne            Stibbons
# 2               Baker          Timothy             Farrell
# 3              Boothe              Tim              Rownam
# 4             Butters           Gerald               Smith
# 5              Coplin             Joan               Baker
# 6             Crumpet            Erica               Smith
# 7                Dare            Nancy            Joplette
# 8             Genting          Matthew             Butters
# 9                Hunt             John             Purview
# 10              Jones            David            Joplette
# 11              Jones          Douglas               Jones
# 12           Joplette           Janice               Smith
# 13          Mackenzie             Anna               Smith
# 14               Owen          Charles               Smith
# 15             Pinker            David             Farrell
# 16            Purview        Millicent               Smith
# 17             Rumney        Henrietta             Genting
# 18             Sarwin        Ramnaresh               Bader
# 19              Smith             Jack               Smith
# 20           Stibbons           Ponder               Tracy
# 21  Worthington-Smyth            Henry               Smith
#
#    recommender_firstname
# 0                 Ponder
# 1                 Ponder
# 2                 Jemima
# 3                    Tim
# 4                 Darren
# 5                Timothy
# 6                  Tracy
# 7                 Janice
# 8                 Gerald
# 9              Millicent
# 10                Janice
# 11                 David
# 12                Darren
# 13                Darren
# 14                Darren
# 15                Jemima
# 16                 Tracy
# 17               Matthew
# 18              Florence
# 19                Darren
# 20                Burton
# 21                 Tracy

# %% [markdown]
# Q12

# %%
run_query("""
SELECT f.name AS facility,
       m.firstname || ' ' || m.surname AS member_name,
       SUM(b.slots) AS total_slots
FROM Bookings AS b
INNER JOIN Facilities AS f ON b.facid = f.facid
INNER JOIN Members AS m ON b.memid = m.memid
WHERE b.memid != 0
GROUP BY f.name, member_name
ORDER BY f.name, member_name
""")
# Out:
#             facility       member_name  total_slots
# 0    Badminton Court    Anna Mackenzie           96
# 1    Badminton Court        Anne Baker           30
# 2    Badminton Court      Burton Tracy            6
# 3    Badminton Court      Charles Owen           18
# 4    Badminton Court      Darren Smith          432
# ..               ...               ...          ...
# 197   Tennis Court 2  Ramnaresh Sarwin           36
# 198   Tennis Court 2        Tim Boothe          168
# 199   Tennis Court 2        Tim Rownam           18
# 200   Tennis Court 2     Timothy Baker           21
# 201   Tennis Court 2       Tracy Smith            6
#
# [202 rows x 3 columns]

# %% [markdown]
# Q13

# %%
run_query("""
SELECT f.name AS facility,
       strftime('%m', b.starttime) AS month,
       SUM(b.slots) AS total_slots
FROM Bookings AS b
INNER JOIN Facilities AS f ON b.facid = f.facid
WHERE b.memid != 0
GROUP BY f.name, month
ORDER BY f.name, month
""")
# Out:
#            facility month  total_slots
# 0   Badminton Court    07          165
# 1   Badminton Court    08          414
# 2   Badminton Court    09          507
# 3    Massage Room 1    07          166
# 4    Massage Room 1    08          316
# 5    Massage Room 1    09          402
# 6    Massage Room 2    07            8
# 7    Massage Room 2    08           18
# 8    Massage Room 2    09           28
# 9        Pool Table    07          110
# 10       Pool Table    08          303
# 11       Pool Table    09          443
# 12    Snooker Table    07          140
# 13    Snooker Table    08          316
# 14    Snooker Table    09          404
# 15     Squash Court    07           50
# 16     Squash Court    08          184
# 17     Squash Court    09          184
# 18     Table Tennis    07           98
# 19     Table Tennis    08          296
# 20     Table Tennis    09          400
# 21   Tennis Court 1    07          201
# 22   Tennis Court 1    08          339
# 23   Tennis Court 1    09          417
# 24   Tennis Court 2    07          123
# 25   Tennis Court 2    08          345
# 26   Tennis Court 2    09          414
